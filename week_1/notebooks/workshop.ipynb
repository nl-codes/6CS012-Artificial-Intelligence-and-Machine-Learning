# %% [markdown]
# # Basic of Image Processing

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image

image_grayed = Image.open("lena_gray.gif")
image_grayed.show()

# %%
print(" Image Format : ", image_grayed.format)
print(" Image Size : ", image_grayed.size)
print(" Image Mode : ", image_grayed.mode)
# Out:
#  Image Format :  GIF
#  Image Size :  (512, 512)
#  Image Mode :  P

# %%
image_colored = Image.open("Lenna_(test_image).png")
image_colored.show()

# %%
print(" Image Format : ", image_colored.format)
print(" Image Size : ", image_colored.size)
print(" Image Mode : ", image_colored.mode)
# Out:
#  Image Format :  PNG
#  Image Size :  (500, 500)
#  Image Mode :  RGB

# %%
# Get the size (width , height) and channels (Gray)
width, height = image_grayed.size
channels = len(image_grayed.getbands())  # For Gray , it will be 3
print(f"Image shape (Gray): ({ height}, {width}, {channels})")
image_size_grayed = width * height * 1
print(f"Image size (Gray): {image_size_grayed}")
# Out:
# Image shape (Gray): (512, 512, 1)
# Image size (Gray): 262144

# %%
# Get the size (width , height) and channels (RGB)
width, height = image_colored.size
channels = len(image_colored.getbands())  # For RGB , it will be 3
print(f"Image shape (RGB): ({ height}, {width}, {channels})")
image_size_colored = width * height * 3
print(f"Image size (RGB): {image_size_colored}")
# Out:
# Image shape (RGB): (500, 500, 3)
# Image size (RGB): 750000

# %%
# Convert the Pillow image to a NumPy array
image_array_colored = np.array(image_colored)
# Display the shape of the NumPy array (height , width ,channels)
print("Shape of the image array:", image_array_colored.shape)
# Out:
# Shape of the image array: (500, 500, 3)

# %%
# Convert the Pillow image to a NumPy array
image_array_grayed = np.array(image_grayed)
# Display the shape of the NumPy array (height , width ,channels)
print("Shape of the image array:", image_array_grayed.shape)
# Out:
# Shape of the image array: (512, 512)

# %%
# Convert the Pillow image to a NumPy array
image_array_colored = np.array(image_colored)
# Display the shape of the NumPy array (height , width , channels)
print("Shape of the colored image array:", image_array_colored.shape)
# For Red Channels
red_channel = image_array_colored[:, :, 0]  # Red channel
print(red_channel)
display(red_channel)
# For Green Channels
green_channel = image_array_colored[:, :, 1]  # Green channel
print(green_channel)
display(green_channel)
# For Blue Channel:
blue_channel = image_array_colored[:, :, 2]  # Blue channel
print(blue_channel)
display(blue_channel)
# Out:
# Shape of the colored image array: (500, 500, 3)
# [[226 225 222 ... 230 221 200]
#  [226 225 222 ... 230 221 200]
#  [226 225 222 ... 230 221 200]
#  ...
#  [ 83  84  92 ... 173 171 176]
#  [ 81  82  95 ... 178 180 184]
#  [ 81  82  96 ... 178 181 185]]
# array([[226, 225, 222, ..., 230, 221, 200],
#        [226, 225, 222, ..., 230, 221, 200],
#        [226, 225, 222, ..., 230, 221, 200],
#        ...,
#        [ 83,  84,  92, ..., 173, 171, 176],
#        [ 81,  82,  95, ..., 178, 180, 184],
#        [ 81,  82,  96, ..., 178, 181, 185]], shape=(500, 500), dtype=uint8)
# [[137 137 136 ... 148 130  99]
#  [137 137 136 ... 148 130  99]
#  [137 137 136 ... 148 130  99]
#  ...
#  [ 17  18  26 ...  72  68  61]
#  [ 21  22  31 ...  69  70  73]
#  [ 21  22  32 ...  69  71  74]]
# array([[137, 137, 136, ..., 148, 130,  99],
#        [137, 137, 136, ..., 148, 130,  99],
#        [137, 137, 136, ..., 148, 130,  99],
#        ...,
#        [ 17,  18,  26, ...,  72,  68,  61],
#        [ 21,  22,  31, ...,  69,  70,  73],
#        [ 21,  22,  32, ...,  69,  71,  74]], shape=(500, 500), dtype=uint8)
# [[124 125 133 ... 122 110  90]
#  [124 125 133 ... 122 110  90]
#  [124 125 133 ... 122 110  90]
#  ...
#  [ 59  59  57 ...  84  76  79]
#  [ 57  57  61 ...  78  80  80]
#  [ 56  57  62 ...  78  81  81]]
# array([[124, 125, 133, ..., 122, 110,  90],
#        [124, 125, 133, ..., 122, 110,  90],
#        [124, 125, 133, ..., 122, 110,  90],
#        ...,
#        [ 59,  59,  57, ...,  84,  76,  79],
#        [ 57,  57,  61, ...,  78,  80,  80],
#        [ 56,  57,  62, ...,  78,  81,  81]], shape=(500, 500), dtype=uint8)

# %%
# --- Red Channel ---
red_channel = image_array_colored[:, :, 0]
# STEP 1: Convert the sliced array back to a PIL Image
red_img_obj = Image.fromarray(red_channel)
# STEP 2: Show the NEW object
red_img_obj.show()

# --- Green Channel ---
green_channel = image_array_colored[:, :, 1]
green_img_obj = Image.fromarray(green_channel)
green_img_obj.show()

# --- Blue Channel ---
blue_channel = image_array_colored[:, :, 2]
blue_img_obj = Image.fromarray(blue_channel)
blue_img_obj.show()

# %%
import matplotlib.pyplot as plt

# 1. Convert Pillow image to NumPy array
image_array_colored = np.array(image_colored)

# 2. Extract Channels correctly
red_channel = image_array_colored[:, :, 0]  # Index 0
green_channel = image_array_colored[:, :, 1]  # Index 1 (Fixed)
blue_channel = image_array_colored[:, :, 2]  # Index 2

# 3. Use Matplotlib to actually SEE them in Colab
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.title("Red Channel")
plt.imshow(red_channel, cmap="Reds")  # cmap shows it in Red shades

plt.subplot(1, 3, 2)
plt.title("Green Channel")
plt.imshow(green_channel, cmap="Greens")

plt.subplot(1, 3, 3)
plt.title("Blue Channel")
plt.imshow(blue_channel, cmap="Blues")

plt.show()

# %%
# Assuming image_colored is already defined and loaded above
# Get the R, G, and B channels
r, g, b = image_colored.split()
# Display or further process the individual channels
display(r)
display(g)
display(b)
# Out:
# <PIL.Image.Image image mode=L size=500x500>
# <PIL.Image.Image image mode=L size=500x500>
# <PIL.Image.Image image mode=L size=500x500>

# %%
# Sample Implementation:
# Accessing a specific row - 100 th row
row_100 = image_array_colored[100, :, :]
# Accessing a specific column - 50 th col
col_50 = image_array_colored[:, 50, :]
# Accessing a specific pixel (row 10, col 20)
pixel = image_array_colored[10, 20, :]  # Gets RGB values at (10 ,20)

print("row 100 ", row_100)
print("col 50", col_50)
print("pixel at (10,20) : ", pixel)
# Out:
# row 100  [[151  61  78]
#  [151  61  78]
#  [152  57  80]
#  ...
#  [214 145 133]
#  [212 141 125]
#  [213 141 126]]
# col 50 [[235 153 120]
#  [235 153 120]
#  [235 153 120]
#  ...
#  [238 162 127]
#  [235 165 125]
#  [235 165 124]]
# pixel at (10,20) :  [223 132 107]

# %%
# Define the cropping box (left , upper , right , lower)
left = 100
upper = 50
right = 200
lower = 150
# Crop the image
cropped_image = image_colored.crop((left, upper, right, lower))
# Display the cropped image
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
# Create a NumPy array (Here , we use a dummy array forillustration)
image_array = np.zeros((100, 100, 3), dtype=np.uint8)  # Example: black image
# Convert the NumPy array back to a Pillow Image object
image_from_array = Image.fromarray(image_array)
# Display the image
image_from_array.show()
# Optionally save the image to a file
image_from_array.save("output_image.jpg")

# %% [markdown]
# # PCA

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Load image and convert to grayscale
image = Image.open("car.jpeg").convert("L")

# Convert to NumPy array
image_array = np.array(image)

# Get image dimensions
height, width = image_array.shape
print("Shape of image : ", height, width)
# Reshape the image into a 2D array where each row represents a row of pixels
# This allows PCA to process each row as an observation and find patterns across pixel intensities
data = image_array.reshape(height, width)
# Out:
# Shape of image :  6720 4480

# %% [markdown]
# ## Step - 1 - Standardize the Data

# %%
# Compute the mean of each column (feature)
mean = np.mean(data, axis=0)

# Subtract mean to center the data
centered_data = data - mean

# %% [markdown]
# ## Step - 2 - Compute Covariance Matrix

# %%
# Compute covariance matrix
cov_matrix = np.cov(centered_data, rowvar=False)

# %% [markdown]
# ## Step - 3 - Compute Eigenvalues & Eigenvectors:

# %%
# Compute eigenvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)

# Sort eigenvalues and corresponding eigenvectors in descending order
sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:, sorted_indices]

# %% [markdown]
# ### Step - 3.1 Picking Principal Components and 3.2 Explained Variance :

# %%
# Plot the explained variance ratio
explained_variance_ratio = eigenvalues / np.sum(eigenvalues)
plt.plot(np.cumsum(explained_variance_ratio))
plt.title("Cumulative Explained Variance")
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Step - 4 - Select Top k Principal Component

# %%
k = 100
components = eigenvectors[:, :k]

# %% [markdown]
# ## Step - 5 - Compress the image

# %%
# Project the data onto the principal components
compressed_data = np.dot(centered_data, components)

# %% [markdown]
# ### Step - 5.1 - Understanding the Compression:

# %%
print(centered_data.shape)
# Out:
# (6720, 4480)

# %%
print(components.shape)
# Out:
# (4480, 100)

# %%
print(compressed_data.shape)
# Out:
# (6720, 100)

# %% [markdown]
# ## Step - 6 - Reconstruct (Decompress) the Image :

# %%
# Reconstruct the image from compressed data
decompressed_data = np.dot(compressed_data, components.T) + mean

# %% [markdown]
# ### Step - 6.1 - Understanding the Reconstruction:

# %%
compressed_data.shape
# Out:
# (6720, 100)

# %%
components.shape
# Out:
# (4480, 100)

# %%
decompressed_data.shape
# Out:
# (6720, 4480)

# %% [markdown]
# ## Step - 7 - Final Visualization:

# %%
plt.figure(figsize=(12, 6))

# Original Image
plt.subplot(1, 3, 1)
plt.imshow(image_array, cmap="gray")
plt.title("Original Image")
plt.axis("off")

# Compressed Representation
plt.subplot(1, 3, 2)
plt.imshow(compressed_data, cmap="gray", aspect="auto")
plt.title(f"Compressed Image (k={k})")
plt.axis("off")

# Decompressed Image
plt.subplot(1, 3, 3)
plt.imshow(decompressed_data, cmap="gray")
plt.title("Decompressed Image")
plt.axis("off")
plt.tight_layout()
plt.show()
